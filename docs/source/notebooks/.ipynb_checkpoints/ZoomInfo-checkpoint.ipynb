# %% [markdown]
# # Zoom Info

# %% [markdown]
# ### **Course Kickoff, Friday March 7 @ 1pm**
# - [Kickoff Meeting Link](https://us06web.zoom.us/j/81826315093?pwd=z2WPqKGwwKMK2o0bCdEHZhpNG6e7Zo.1)
#
# ### **Mandatory Zoom Meetings**
# Students are required to attend mandatory meetings on the following dates:
# - **Tuesdays at 1 PM** on **March 11, March 25, April 1, April 8, and April 15**.
# - No mandatory meeting during Spring Break - Mar 18
# - [Mandatory Meeting Zoom Link](https://us06web.zoom.us/j/87850495731?pwd=3AeGx7WNTVA6g0jQww3DJf2tRxOkXU.1)

# %% [markdown]
# ### **Zoom Etiquette for CMI Sessions**
#
# To ensure a smooth and engaging experience for everyone, please follow these Zoom etiquette guidelines during our guest speaker sessions:
#
# #### ✅ **Cameras On**
# We encourage you to keep your **cameras on** during the session. Seeing faces fosters engagement and a more interactive discussion.
#
# #### 🔇 **Mute When Not Speaking**
# Please keep your **microphone muted** unless you are actively asking a question. This helps minimize background noise and distractions.
#
# #### 🎤 **How to Ask Questions**
# - If you have a question, either **raise your hand** (Zoom feature) or type it in the chat.
# - Unmute yourself only when it’s your turn to speak.
#
# #### 🎨 **Backgrounds**
# - Thematic or virtual backgrounds are fine, but **please avoid anything too distracting** (e.g., animations, bright patterns).
# - If possible, choose a neutral or professional background.
#
# #### 🖥 **Be Present & Engaged**
# - Minimize multitasking—these sessions are interactive and meant to be valuable for you.
#
# Thanks for your cooperation, and looking forward to seeing you all there! 🚀

# %% [markdown]
# ### **Office Hours**
# - **Instructor:** Beverly Rice
# - **Email:** ricebg@hawaii.edu
# - **Office Hours:** Thu 6pm (zoom), Fri 12pm (zoom + Chaminade), Also available upon request
#         - [Officer Hours Zoom Link](https://us06web.zoom.us/j/83826697863?pwd=I6Fg72l7AFx6bZoecSUHpseOUSbzdi.1)
