# %% [markdown]
# # 📝 Week 2 Assignment

# %% [markdown]
# ## Evaluating Bias and Algorithmic Challenges
#
# ⏳ **Estimated Duration:** 2-3 Hours
# 🎯 **Due:** Friday, 21 March at 11:59pm
#
# ---
#
# **Assignment Overview**
# This assignment is designed to help you critically evaluate the challenges of **data bias and AI-driven misinformation detection** through real-world case studies. By analyzing the two case studies, you will assess the limitations of misinformation detection models, explore algorithmic bias, and propose strategies for mitigating bias in misinformation research.
#
# By the end of this assignment, you will have developed an understanding of:
# - ✅ The risks of **single-platform misinformation detection models**
# - ✅ The ethical dilemmas of **AI-driven misinformation detection**
# - ✅ The impact of **bias and transparency concerns** in misinformation research
#
# ---
#
# **📌 Instructions**
#
# **Review the Two Case Studies in GitHub Discussions**
# Carefully read and analyze the discussions in the two GitHub case studies:
#
# 1️⃣ **[Case Study 1: The Limitations of Single-Platform Misinformation Detection](https://github.com/BevRice/CMI_Course/discussions/4)**
#
# - What are the risks of developing a misinformation detection system trained on data from a single social media platform?
# - How might misinformation patterns differ across platforms (e.g., Twitter vs. TikTok vs. Facebook)?
# - What steps could researchers take to ensure a broader, more representative dataset while maintaining efficiency?
# - If platform restrictions (e.g., API access limitations) prevent multi-platform data collection, what alternative solutions could mitigate bias?
#
#
# 2️⃣ **[Case Study 2: Algorithmic Bias in AI-Powered Misinformation Detection](https://github.com/BevRice/CMI_Course/discussions/5)**
# - Should they adjust the AI model to allow for more human moderation, or would this introduce additional bias?
# - How can they balance misinformation detection without infringing on free speech?
# - Should platforms be fully transparent about how their AI models detect and flag misinformation?
#
# ---
#
# **🚀 Submission Guidelines**
# - ✅ Comment 2 separate **500-1000 word responses** one for each discussion
# - ✅ After posting your analysis, **respond to at least one other participant's post** with an insightful comment, counterpoint, or further question
# - ✅ Cite any additional sources.
#
# ---
#
# **Rubric: Evaluating Bias and Algorithmic Challenges**
#
# **1️⃣ Depth of Analysis (10 points)**
# Evaluates how well the student examines the case studies, identifies key biases, and proposes mitigation strategies.
#
# | **Criteria** | **Points** |
# |-------------|-----------|
# | **Exceptional (9-10 pts)**: Provides a thorough and insightful analysis of both case studies. Clearly identifies key challenges and bias types (selection bias, algorithmic bias, etc.). Proposes well-reasoned solutions with real-world relevance. | **9-10** |
# | **Proficient (7-8 pts)**: Addresses the main aspects of both case studies but lacks depth in one or two areas. Identifies major biases but does not fully explore mitigation strategies. | **7-8** |
# | **Basic (5-6 pts)**: Discusses both case studies but in a surface-level manner. Lacks depth in bias identification or problem-solving strategies. | **5-6** |
# | **Needs Improvement (0-4 pts)**: Incomplete or vague analysis. Does not address key issues in case studies. | **0-4** |
#
# ---
#
# **2️⃣ Use of Evidence and Examples (5 points)**
# Assesses the ability to support claims with examples from the case studies, discussions, and real-world cases.
#
# | **Criteria** | **Points** |
# |-------------|-----------|
# | **Exceptional (5 pts)**: Effectively integrates multiple examples from the case studies and GitHub Discussions. Includes at least one external real-world example. | **5** |
# | **Proficient (4 pts)**: Uses case study examples but lacks additional real-world context. | **4** |
# | **Basic (3 pts)**: References case studies but does not provide specific supporting details. | **3** |
# | **Needs Improvement (0-2 pts)**: Little to no use of case study evidence. Arguments feel unsupported. | **0-2** |
#
# ---
#
# **3️⃣ Engagement with Peer Responses (5 points)**
# Evaluates participation in the GitHub Discussion, including thoughtful responses to at least one other post.
#
# | **Criteria** | **Points** |
# |-------------|-----------|
# | **Exceptional (5 pts)**: Engages in meaningful discussion by responding to at least one peer with **insightful analysis, counterpoints, or further questions**. Expands on the conversation. | **5** |
# | **Proficient (4 pts)**: Responds to a peer’s post with relevant points but lacks depth or additional analysis. | **4** |
# | **Basic (3 pts)**: Responds briefly but does not meaningfully contribute to the discussion. | **3** |
# | **Needs Improvement (0-2 pts)**: No engagement or very minimal response. | **0-2** |
#
# ---
#
# **📌 Final Score Breakdown**
# | **Category** | **Max Points** | **Your Score** |
# |-------------|--------------|--------------|
# | **Depth of Analysis** | 10 |  |
# | **Use of Evidence & Examples** | 5 |  |
# | **Engagement with Peer Responses** | 5 |  |
# | **Total Score (out of 20)** | 20 |  |
